# %%
import numpy as np

# %%
arr1 = np.array([1, 5 , 8, 6]) # bir o'lchamli massivning oddiy turi
arr1
# Out:
# array([1, 5, 8, 6])

# %%
arr1.ndim
# Out:
# 1

# %%
arr1 = np.array(arr1, dtype = np.float64) # massivning tipini belgilash
arr1
# Out:
# array([1., 5., 8., 6.])

# %%
arr2 = np.array([4 , 5, 7], dtype = np.int32)
arr2
# Out:
# array([4, 5, 7], dtype=int32)

# %%
arr1.dtype # massivning tipini aniqlash
# Out:
# dtype('float64')

# %%
arr2.dtype
# Out:
# dtype('int32')

# %%
arr3 = np.array([1, 8 , 3, 5]) #numpy da bu massiv o'z o'zi tip tanlaydi yaniy int64 ni
arr3
# Out:
# array([1, 8, 3, 5])

# %%
arr3.dtype
# Out:
# dtype('int64')

# %%
float_arr = arr3.astype(np.float64) # bu yerda int64 tipindagi massivni float64 tipiga o'girdik
float_arr
# Out:
# array([1., 8., 3., 5.])

# %%
data = np.array([4.0, 5, 7, 2.5])
data
# Out:
# array([4. , 5. , 7. , 2.5])

# %%
data.dtype
# Out:
# dtype('float64')

# %%
int_arr = data.astype(np.int32) # float64 tipidagi massivni int32 turiga o'zgartirdik
int_arr
# Out:
# array([4, 5, 7, 2], dtype=int32)
