# %%
import numpy as np

# %%
my_list = list(range(100_000)) # python list 0~99999 -->Normal
my_array = np.array(range(100_000)) # numpy array(massiv) 0~99999 --> Vektorlashgan

# %%
# %time for _ in range(10): [x*2 for x in my_list] # Normal
# Out:
# CPU times: user 68.7 ms, sys: 5.95 ms, total: 74.6 ms
# Wall time: 74.8 ms

# %%
# %time for _ in range(10): my_array * 2
# Out:
# CPU times: user 2.32 ms, sys: 0 ns, total: 2.32 ms
# Wall time: 1.79 ms

# %%
83.5/4.44
# Out:
# 18.806306306306304
